# %% [markdown]
# # MATH 210 Introduction to Mathematical Computing
#
# **April 12, 2024**

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as la

# %% [markdown]
# Generate fake data:

# %%
N = 200
x = 1.5*np.random.rand(N)
y = x*(1 - x) + 0.02*np.random.randn(N)

# %% [markdown]
# Without looking at the code above, look at the plot and code below and predict the output:

# %%
plt.scatter(x,y)
plt.show()

# %%
X = np.column_stack([x**0,x**1,x**2])
c = la.solve(X.T@X,X.T@y)
print(c)
# Out:
# [ 0.00521945  0.97094326 -0.98067084]

# %%
c.round(2)
# Out:
# array([ 0.01,  0.97, -0.98])
